# %% [markdown]
# <a href="https://colab.research.google.com/github/VladimirApter/logica_course_2025/blob/main/Logic_Programming_2025%2C_Homework_3_Vladimir_Apter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logic Programming Homework 3
#
# **PLEASE FILL IN:**
#
# _Владимир Аптер_
#
# _vova.apter@yandex.ru_
#
# ## Problems
#
# Input table is `logica_home.Salaries`, with salaries of employees of San Francisco by year.
#
# 1. The table has a bug: sometimes name have double spaces. Fix the bug by creating an version of the table, where this bug is fixed and double spaces as well as outter spaces are removed. It’s OK to keep only the columns you need for the following problems.
#
# 2. Add to this database a table for predicate:
# `RoleInfo(role_name:, num_people:, average_pay:)`
# that shows the number of people in the role and average pay for people in the role.  Have it ordered by `role_name`. `total_pay` column should be used for `average_pay`.
#
# 3. Add to this database a table corresponding to the following predicate:
# `PersonInfo(name:, latest_total_pay:, pay_by_year:, pay_relative_to_role:)`
# which for each person stores payment they’ve got in the last year that they worked, a list of `{year:, pay:}` structs with pay for each year and how much they get paid relative to the average for the role. Order it by `latest_total_pay` starting from the largest. `total_pay` column should be used for all of `latest_total_pay`, `pay_by_year`, `pay_relative_to_role`. `pay_relative_to_role` should be computed for the last year they were employed.
#
# 4. Write predicate `TopPaid(name:, total_pay:)` with 10 people who earned the most in total over all the years they worked.
#
# 5. Write a predicate `PayIncrease(person) = increase` showing how much their pay increased from the first to the last year they worked. This predicate may only use `PersonInfo` and must be non-aggregating, i.e. using aggregating expression for getting the increase.
#
#
#
#
# Source: https://www.kaggle.com/kaggle/sf-salaries

# %% [markdown]
# ## Loading data

# %%
# !gdown https://drive.google.com/uc?id=1PlGcott1Vr9Tm4Rjb3v4bvQC4EjUfHT9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PlGcott1Vr9Tm4Rjb3v4bvQC4EjUfHT9
# To: /content/homework_1.tar.gz
# 100% 5.14M/5.14M [00:00<00:00, 39.9MB/s]

# %%
# !tar -xzvf homework_1.tar.gz
# Out:
# homework_1.sql

# %%
# !git clone -b ti2023 https://github.com/evgskv/logica
# Out:
# Cloning into 'logica'...
# remote: Enumerating objects: 5377, done.
# remote: Counting objects: 100% (1305/1305), done.
# remote: Compressing objects: 100% (263/263), done.
# remote: Total 5377 (delta 1125), reused 1098 (delta 1037), pack-reused 4072 (from 1)
# Receiving objects: 100% (5377/5377), 6.68 MiB | 14.50 MiB/s, done.
# Resolving deltas: 100% (3557/3557), done.

# %%
from logica import colab_logica

# %%
colab_logica.PostgresJumpStart()
# Out:
# Installing and configuring an empty PostgreSQL database.
# Installation succeeded. Connecting...
# Connected.

# %%
# %%logica Init
#
# Init("done")
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id1"></div>
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id2"></div>
# The following query is stored at Init_sql variable.
# -- Initializing PostgreSQL environment.
# set client_min_messages to warning;
# create schema if not exists logica_home;
# -- Empty logica type: logicarecord893574736;
# DO $$ BEGIN if not exists (select 'I(am) :- I(think)' from pg_type where typname = 'logicarecord893574736') then create type logicarecord893574736 as (nirvana numeric); end if; END $$;
#
#
# DO $$
# BEGIN
# -- Logica type: logicarecord481217614
# ...

# %%
# Importing data.
# !PGPASSWORD=logica psql -U logica -d logica -h localhost -f homework_1.sql -v ON_ERROR_STOP=1 | head -n 100
# Out:
# SET
# SET
# SET
# SET
# SET
#  set_config
# ------------
#
# (1 row)
#
# SET
# SET
# SET
# SET
# SET
# SET
# CREATE TABLE
# ALTER TABLE
# COPY 148650

# %% [markdown]
# ## Solving problems

# %%
# %%logica Q, WithoutDoubleSpaces, RoleInfo
#
# @Limit(Q, 10);
# Q(..r) :- logica_home.Salaries(..r);
#
# WithoutDoubleSpaces(employee_name:name_without_spaces, role_name:, total_pay:, year:) :-
#     logica_home.Salaries(employee_name:, job_title:role_name, total_pay:, year:),
#     name_without_triple_spaces == Join(Split(employee_name, "   "), " "),
#     name_without_spaces == Join(Split(name_without_triple_spaces, "  "), " ");
#
# @OrderBy(RoleInfo, "role_name");
# RoleInfo(role_name:, num_people? += 1, average_pay? Avg= total_pay) distinct :-
#     WithoutDoubleSpaces(role_name:, total_pay:);
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id162"></div>
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id163"></div>
# The following query is stored at Q_sql variable.
# -- Initializing PostgreSQL environment.
# set client_min_messages to warning;
# create schema if not exists logica_home;
# -- Empty logica type: logicarecord893574736;
# DO $$ BEGIN if not exists (select 'I(am) :- I(think)' from pg_type where typname = 'logicarecord893574736') then create type logicarecord893574736 as (nirvana numeric); end if; END $$;
#
#
# DO $$
# BEGIN
# -- Logica type: logicarecord481217614
# ...

# %%
# %%logica PayByTitle
#
# PayByTitle(job_title:, average_pay? Avg= total_pay, max_pay? Max= total_pay) distinct :-
#   logica_home.Salaries(job_title:, total_pay:);
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id5"></div>
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id6"></div>
# The following query is stored at PayByTitle_sql variable.
# -- Initializing PostgreSQL environment.
# set client_min_messages to warning;
# create schema if not exists logica_home;
# -- Empty logica type: logicarecord893574736;
# DO $$ BEGIN if not exists (select 'I(am) :- I(think)' from pg_type where typname = 'logicarecord893574736') then create type logicarecord893574736 as (nirvana numeric); end if; END $$;
#
#
# DO $$
# BEGIN
# -- Logica type: logicarecord481217614
# ...
