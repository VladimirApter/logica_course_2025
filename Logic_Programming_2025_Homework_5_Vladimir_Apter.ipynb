# %% [markdown]
# <a href="https://colab.research.google.com/github/VladimirApter/logica_course_2025/blob/main/Logic_Programming_2025_Homework_5_Vladimir_Apter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logic Programming Homework 5
#
# PLEASE FILL IN:
#
# _Владимир Аптер_
#
# _vova.apter@yandex.ru_
#
#
# 1. Write Prod custom aggregate function (для этого нужна смекалка!) that computes product of the numbers it aggregates (like Sum computes the sum). Use it to build Power2(n:, p:) predicate that shows p = $2^n$ for n = 0..10. **Do not use recursion here.**
# 2. We live in 2D world on a planet named Earth located at (0, 0). Alien spaceship is traveling on trajectory y = 3 + x * x - x. We want to meet the aliens at the point of their travel, which is closest to Earth. Write predicate MeetingPoint(x, y), where (x, y) would **approximately** be the nearest point to Earth located on the alien spaceship trajectory.
# 3. Given football stats data find:
#   * 10 teams that won most matches
#   * Were there ever 3 matches so that A won B, B won C, C won A? Produce a row of the form "A-B-C" for each such triple, where A, B, C are substituted with the names of teams.
# For perfect score on this question your program must be easy to read.
#   * Write a predicate that verifies that winner assignment in the table matches the score.

# %%
# !git clone https://github.com/evgskv/logica
# Out:
# fatal: destination path 'logica' already exists and is not an empty directory.

# %%
from logica import colab_logica
colab_logica.PostgresJumpStart()
# Out:
# Installing and configuring an empty PostgreSQL database.
# Installation succeeded. Connecting...
# Connected.

# %% [markdown]
# ## Data

# %%
# !gdown https://drive.google.com/uc?id=1qRr_EtRcr7YNJNnLDt6QD5wjaCPzqKvU
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qRr_EtRcr7YNJNnLDt6QD5wjaCPzqKvU
# To: /content/homework_4.tar.gz
# 100% 933k/933k [00:00<00:00, 84.8MB/s]

# %%
# !tar -xzvf homework_4.tar.gz
# Out:
# homework_4.sql

# %%
# Importing data.
# !PGPASSWORD=logica psql -U logica -d logica -h localhost -f homework_4.sql -v ON_ERROR_STOP=1 | head -n 100
# Out:
# SET
# SET
# SET
# SET
# SET
#  set_config
# ------------
#
# (1 row)
#
# SET
# SET
# SET
# SET
# CREATE SCHEMA
# ALTER SCHEMA
# CREATE TYPE
# ALTER TYPE
# CREATE TYPE
# ALTER TYPE
# CREATE TYPE
# ALTER TYPE
# SET
# SET
# CREATE TABLE
# ALTER TABLE
# COPY 123405

# %% [markdown]
# ## Solution

# %%
# %%logica Q
#
# Q(..r) :- logica_home.Matches(..r);
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id3"></div>
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id4"></div>
# The following query is stored at Q_sql variable.
# -- Initializing PostgreSQL environment.
# set client_min_messages to warning;
# create schema if not exists logica_home;
# -- Empty logica type: logicarecord893574736;
# DO $$ BEGIN if not exists (select 'I(am) :- I(think)' from pg_type where typname = 'logicarecord893574736') then create type logicarecord893574736 as (nirvana numeric); end if; END $$;
#
#
# DO $$
# BEGIN
# -- Logica type: logicarecord481217614
# ...
